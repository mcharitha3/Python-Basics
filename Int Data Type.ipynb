# %% [markdown]
# Basic to know the type of a variable

# %%
x=5
type(x)
# Out:
# int

# %%
x=5
y=10 #Decimal
y=0xA #Hexadecimal
y=0o12 #Octal
y=0b1010 #Binary
print('x=', x,',' 'y=',y)
# Out:
# x= 5 ,y= 10

# %% [markdown]
# Comparisions on INT

# %%
print('x==y =', x==y)
print('x!=y =', x!=y)
print('x>=y =', x>=y)
print('x<=y =', x<=y)
print('x>y =', x>y)
print('x<y =', x<y)
# Out:
# x==y = False
# x!=y = True
# x>=y = False
# x<=y = True
# x>y = False
# x<y = True

# %% [markdown]
# Usual Operations

# %%
print('x+y=', x+y)
print('x-y=', x-y)
print('x*y=', x*y)
print('x/y=', x/y)
print('x%y=', x%y)
print('x**y=', x**y)
print('x//y=', x//y)
# Out:
# x+y= 15
# x-y= -5
# x*y= 50
# x/y= 0.5
# x%y= 5
# x**y= 9765625
# x//y= 0

# %%
x=5
x.bit_length()
# Out:
# 3

# %%
y=3+4j
y.conjugate()
# Out:
# (3-4j)

# %%
x=3+4j
type(x)
x.imag
# Out:
# 4.0

# %%
int.mro?

# %%
x=3+5j
x.real
# Out:
# 3.0

# %%
x=5
x.to_bytes(2,'big')
#x.to_bytes(4,'little')
# Out:
# b'\x00\x05'

# %% [markdown]
# # DOUBTS

# %% [markdown]
# int.denominator
# int.numerator
# int.from_bytes
# int.mro
# What does 'getset descriptor' means?
